# %% [markdown]
# #  Objective of this souce code:
# ### 1- Inspect the dataframe (created in I), filter the non necessary data and fill the missing records.
# ### 2- Generate the correspondant dataframe.

# %%
# I.
# -*- coding: utf-8 -*-

import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

import geopandas as gpd
from area import area
import numpy as np

# II
# Reading the main reference df: wlands.

wlands = pd.read_csv('/home/hmdg/Documents/Data_Science/Repos/Lands/data/wlands.csv', 
                      header=0, encoding='iso8859_1')

wlands.columns
# Reorder the columns 
wlands = wlands[['name_w', 'region_country','regionw','type', 'value','year', 'continent', 
                 'pop_est', 'geometry','number', 'iso_a3', 'gdp_md_est', 'footnotes', 
                  'source', 'general_source']]

# %% [markdown]
# Let's inspect the data.

# %%
wlands_16 = wlands[wlands.year==2016]
wcount = wlands_16.groupby(['name_w']).count()
wun = wcount['type'].unique()

# %% [markdown]
# - This list {{wun}} are the differents values for lands types per country.
# - Those over 8, are more than expected; and under 8, are missing.
#
# We'll work at first this with surplus values.

# %%
wcount = wlands_16.groupby(['name_w']).count()
wcount[wcount['type']>8]
# Out:
#              region_country  regionw  type  value  year  continent  pop_est  \
# name_w
# China                    16       16    16     16    16         16       16
# Netherlands              11       11    11     11    11         11       11
#
#              geometry  number  iso_a3  gdp_md_est  footnotes  source  \
# name_w
# China              16      16      16          16         13      16
# Netherlands        11      11      11          11          7      11
#
#              general_source
# name_w
# China                    16
# Netherlands              11

# %% [markdown]
# Are China and Netherlands this that has extra values.
# Let's zoom them.

# %%
wlands_16[(wlands_16['name_w'].isin(['China','Netherlands']))
         & (wlands_16['type']=='Land area (thousand hectares)')]
# Out:
#            name_w                 region_country                regionw  \
# 2873  Netherlands                    Netherlands  Europe & Central Asia
# 2892  Netherlands  Netherlands Antilles [former]  Europe & Central Asia
# 4066        China                          China    East Asia & Pacific
# 4087        China           China, Hong Kong SAR    East Asia & Pacific
# 4098        China               China, Macao SAR    East Asia & Pacific
#
#                                type     value  year continent     pop_est  \
# 2873  Land area (thousand hectares)    3369.0  2016    Europe    17084719
# 2892  Land area (thousand hectares)      80.0  2016    Europe    17084719
# 4066  Land area (thousand hectares)  938821.0  2016      Asia  1379302771
# 4087  Land area (thousand hectares)     105.0  2016      Asia  1379302771
# 4098  Land area (thousand hectares)       3.0  2016      Asia  1379302771
#
#                                                geometry  number iso_a3  \
# 2873  POLYGON ((6.905139601274129 53.48216217713065,...     528    NLD
# 2892  POLYGON ((6.905139601274129 53.48216217713065,...     530    NLD
# 4066  MULTIPOLYGON (((109.4752095886636 18.197700913...     156    CHN
# 4087  MULTIPOLYGON (((109.4752095886636 18.197700913...     344    CHN
# 4098  MULTIPOLYGON (((109.4752095886636 18.197700913...     446    CHN
#
#       gdp_md_est                                          footnotes  \
# 2873    870800.0                                          Estimate.
# 2892    870800.0                                                NaN
# 4066  21140000.0  Estimate.;For statistical purposes, the data f...
# 4087  21140000.0                                          Estimate.
# 4098  21140000.0                                                NaN
#
#                                                  source        general_source
# 2873  Food and Agriculture Organization of the Unite...  https://data.un.org/
# 2892  Food and Agriculture Organization of the Unite...  https://data.un.org/
# 4066  Food and Agriculture Organization of the Unite...  https://data.un.org/
# 4087  Food and Agriculture Organization of the Unite...  https://data.un.org/
# 4098  Food and Agriculture Organization of the Unite...  https://data.un.org/

# %% [markdown]
# - The 'name_w' column is the reference, and the 'region_country' is the name comming from the Land df.
# - In both cases, we can see that even that the values of every type of land change, the geometry is the same for every country named in 'name_w'.
# - Hence, in the map plot, it'll be not possible to draw the different locations.
#
# So, this extra columns are going to be excluded.

# %%
wlands_16 = wlands_16[~wlands_16['region_country'].isin(['Netherlands Antilles [former]', 
                                              'China, Hong Kong SAR',
                                             'China, Macao SAR'])]

# %% [markdown]
# Let's work just with the year 2016, and do some math.

# %%
countries = len(wlands_16['name_w'].unique())
expected = 8 * countries
actual_registers = wlands_16.shape[0]
diffe = expected - actual_registers

# %% [markdown]
# - Notes:
#     - There are {{countries}} differentes countries.
#     - If every country has 8 differents types of land, we are specting to have {{expected}} registers in the dataframe; and we actually have {{actual_registers}} registers.
#     - This means, are {{diffe}} missing.

# %%
wc = wlands_16.groupby(['type']).count()
wc.year.sort_values(ascending=False)
# Out:
# type
# Forest cover (thousand hectares)                                                       170
# Land area (thousand hectares)                                                          168
# Forest cover (% of total land area)                                                    168
# Arable land (thousand hectares)                                                        167
# Arable land (% of total land area)                                                     166
# Important sites for terrestrial biodiversity protected (% of total sites protected)    165
# Permanent crops (thousand hectares)                                                    164
# Permanent crops (% of total land area)                                                 163
# Name: year, dtype: int64

# %%
# Missing records from which countries?

wo = wlands_16.groupby(['name_w']).count()
wless = 8 - wo.type[wo.type<8]
print(wless, '\nTotal missing: ', wless.sum() )

wlist = wless.index.tolist() # List of countries with missing registers
w_16=wlands_16[wlands_16['name_w'].isin(wlist)]
# Out:
# name_w
# Djibouti                    2
# Falkland Is.                4
# Greenland                   4
# Guyana                      1
# Iceland                     2
# Jordan                      1
# Peru                        1
# S. Sudan                    6
# Sudan                       4
# United States of America    1
# W. Sahara                   3
# Name: type, dtype: int64
# Total missing:  29

# %%
# Which has no Land Area?

wo = w_16.groupby(['name_w','type']).count()
wo = wo.reset_index(level=['type'])
wo = wo.pivot(columns='type', values='value')
wo.style.highlight_null(null_color='yellow')
# Out:
# <style  type="text/css" >
#     #T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col6 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col7 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col0 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col1 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col6 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col7 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col0 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col1 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col6 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col7 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow3_col4 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow4_col6 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow4_col7 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow5_col4 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow6_col4 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow7_col0 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow7_col1 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow7_col2 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow7_col5 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow7_col6 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow7_col7 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow8_col0 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow8_col2 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow8_col5 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow8_col6 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow9_col4 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow10_col4 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow10_col6 {
#             background-color:  yellow;
#         }    #T_3f569d62_04dd_11eb_917a_7bb63586074arow10_col7 {
#             background-color:  yellow;
#         }</style><table id="T_3f569d62_04dd_11eb_917a_7bb63586074a" ><thead>    <tr>        <th class="index_name level0" >type</th>        <th class="col_heading level0 col0" >Arable land (% of total land area)</th>        <th class="col_heading level0 col1" >Arable land (thousand hectares)</th>        <th class="col_heading level0 col2" >Forest cover (% of total land area)</th>        <th class="col_heading level0 col3" >Forest cover (thousand hectares)</th>        <th class="col_heading level0 col4" >Important sites for terrestrial biodiversity protected (% of total sites protected)</th>        <th class="col_heading level0 col5" >Land area (thousand hectares)</th>        <th class="col_heading level0 col6" >Permanent crops (% of total land area)</th>        <th class="col_heading level0 col7" >Permanent crops (thousand hectares)</th>    </tr>    <tr>        <th class="index_name level0" >name_w</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f569d62_04dd_11eb_917a_7bb63586074alevel0_row0" class="row_heading level0 row0" >Djibouti</th>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col1" class="data row0 col1" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col3" class="data row0 col3" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col5" class="data row0 col5" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow0_col7" class="data row0 col7" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_3f569d62_04dd_11eb_917a_7bb63586074alevel0_row1" class="row_heading level0 row1" >Falkland Is.</th>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col2" class="data row1 col2" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col3" class="data row1 col3" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col4" class="data row1 col4" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col5" class="data row1 col5" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col6" class="data row1 col6" >nan</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow1_col7" class="data row1 col7" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_3f569d62_04dd_11eb_917a_7bb63586074alevel0_row2" class="row_heading level0 row2" >Greenland</th>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col1" class="data row2 col1" >nan</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col3" class="data row2 col3" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col4" class="data row2 col4" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col5" class="data row2 col5" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col6" class="data row2 col6" >nan</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow2_col7" class="data row2 col7" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_3f569d62_04dd_11eb_917a_7bb63586074alevel0_row3" class="row_heading level0 row3" >Guyana</th>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow3_col0" class="data row3 col0" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow3_col1" class="data row3 col1" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow3_col2" class="data row3 col2" >1</td>
#                         <td id="T_3f569d62_04dd_11eb_917a_7bb63586074arow3_col3" class="data row3 col3"

# %% [markdown]
# ### From the last table, we can see the missing types of land per country. Are in total 29 rows.
# ### Now we'll add the quantity of rows needed, it'll be merge with the original table, and then we will fill with the correspondant value.

# %%
# Adding the quantity of missing rows.

def concat_list(df):
    left = []
    simple = []
    types = df.type.unique().tolist()
    rc = df['region_country'].unique().tolist()
    geom = df['geometry'].unique().tolist()
    c = 0
    for s in df['name_w'].unique():
        l_pc = df['type'][df['name_w']==s].tolist()
        for t in types:
            co = df['continent'][df.name_w==s].unique()[0]
            rw = df['regionw'][df.name_w==s].unique()[0]
            poe = df['pop_est'][df.name_w==s].unique()[0]
            geom = df['geometry'][df.name_w==s].unique()[0]
            num = df['number'][df.name_w==s].unique()[0]
            iso = df['iso_a3'][df.name_w==s].unique()[0]
            gpd = df['gdp_md_est'][df.name_w==s].unique()[0]
            if t not in l_pc:
                # the NaN spaces are the numbers of columns of the df reference
                simple.append([s,rc[c],rw, t,'',2016, co, poe, geom, num, iso, gpd,'','',''])
        c += 1
    return(simple)


l_simple = concat_list(w_16)#[1] # Reference list with no empty spaces
l_att = pd.DataFrame(l_simple, columns=(w_16.columns.tolist()))

# Fixing name problem
wlands_16['name_w'] = wlands_16['name_w'].str.replace("C̫te d'Ivoire", 'Cote dIvoire')
wlands_16['region_country'] = wlands_16['region_country'].str.replace("C̫te d'Ivoire", 'Cote dIvoire')


wlands16 = pd.concat([wlands_16, l_att], sort=False, axis=0).reset_index(drop=True)

# %% [markdown]
# - The missing data can be classified in two:
#     - this ones that has to be taken from external source.
#     - some others that can be calculated from data that we already has. (F. ex. Forrest cover (%) can be obtained from Forrest Cover Ha and Land area).
#
# We'll began with the first case: data taken from external source.
# For this, it's going to be fill a table and then imported here.

# %%
# Save to csv the missing reference table
l_simple = pd.DataFrame(l_simple, columns=wlands16.columns)

l_simple.to_csv(r'/home/hmdg/Documents/Data_Science/Repos/Lands/data/l_simple.csv', index = False)

# %%
# Open the csv of the missing records already filled

l_simple_mod = pd.read_csv('/home/hmdg/Documents/Data_Science/Repos/Lands/data/l_simple_mod.csv', 
                      header=0, encoding='iso8859_1')

# %%
# Merging the table with the missing values to the reference one (wlands_16)

wlands16 = pd.concat([wlands_16, l_simple_mod], sort=False, axis=0).reset_index(drop=True)
wlands16 = wlands16.sort_values(by='name_w')

wl = wlands16.copy()

# %%
# II
# # Create the acronyme of the land types
wl['a_type'] = ''

lrep = {'Land area (thousand hectares)':'LA',
        'Arable land (thousand hectares)': 'AL', 'Arable land (% of total land area)':'AL_%',
        'Forest cover (thousand hectares)':'FC', 'Forest cover (% of total land area)':'FC_%',
        'Permanent crops (thousand hectares)':'PC','Permanent crops (% of total land area)':'PC_%',
        'Important sites for terrestrial biodiversity protected (% of total sites protected)':'IB%'}

wl['a_type'] = wl['type'].map(lrep)

# %%
# Data frame with the countrys of the merged tables:
    # geopandas df
    # lands from the UN statistics
    # missing data
    
wl.to_csv(r'/home/hmdg/Documents/Data_Science/Repos/Lands/data/wl.csv', index = False)
